# %% [markdown]
# Ques-> 1. What are Python’s built-in data types?

# %% [markdown]
# # Built-in Data Types
#
# - Numeric → int, float, complex
#
# - Sequence → str, list, tuple, range
#
# - Set → set, frozenset
#
# - Mapping → dict
#
# - Boolean → bool
#
# - Binary → bytes, bytearray, memoryview
#
# # User-defined Data Types
#
# - Classes
#
# - Objects
#
# # definitions_of_each_data_type
#
#
#
#
# # 🔹 Data Types in Python
#
# ## 1. **Built-in Data Types**
#
# ---
#
# ### **A. Numeric Types**
#
# * **int** → Whole numbers.
#   📌 *Example*: Number of apples in a basket → `10`.
#
# * **float** → Decimal numbers.
#   📌 *Example*: Temperature outside → `36.5 °C`.
#
# * **complex** → Numbers with real and imaginary part.
#   📌 *Example*: Used in **engineering/electricity** to represent circuits → `2 + 3j`.
#
# ---
#
# ### **B. Sequence Types**
#
# * **str** → Text inside quotes.
#   📌 *Example*: Your name `"Chirag"`.
#
# * **list** → Ordered collection, changeable.
#   📌 *Example*: A shopping list → `["milk", "bread", "eggs"]`.
#
# * **tuple** → Ordered collection, unchangeable.
#   📌 *Example*: Coordinates of a location → `(28.61, 77.23)`.
#
# * **range** → Sequence of numbers.
#   📌 *Example*: Roll numbers from `1 to 50` in a class.
#
# ---
#
# ### **C. Set Types**
#
# * **set** → Unordered collection, unique values only.
#   📌 *Example*: Colors in a box of crayons → `{red, blue, green}` (no duplicates).
#
# * **frozenset** → Same as set but cannot be changed.
#   📌 *Example*: Fixed set of weekdays → `{Mon, Tue, Wed, Thu, Fri, Sat, Sun}`.
#
# ---
#
# ### **D. Mapping Type**
#
# * **dict** → Stores key-value pairs.
#   📌 *Example*: A contact book → `{ "Rahul": 9876543210, "Amit": 9123456789 }`.
#
# ---
#
# ### **E. Boolean Type**
#
# * **bool** → Either True or False.
#   📌 *Example*: Is the light on? → `True` / `False`.
#
# ---
#
# ### **F. Binary Types**
#
# * **bytes** → Immutable sequence of bytes (used in data storage).
#   📌 *Example*: An image saved in memory.
#
# * **bytearray** → Mutable sequence of bytes.
#   📌 *Example*: Editing an image file.
#
# * **memoryview** → Window to access binary data.
#   📌 *Example*: Viewing part of a big video file without copying it fully.
#
# ---
#
# ## 2. **User-defined Data Types**
#
# * **Class** → A blueprint/template created by programmer.
#   📌 *Example*: A "Car" class defines properties like color, brand, speed.
#
# * **Object** → A real instance of a class.
#   📌 *Example*: A red Toyota car made from the "Car" class.
